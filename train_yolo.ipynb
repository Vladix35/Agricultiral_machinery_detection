# %%
from ultralytics import YOLO
import torch
torch.cuda.empty_cache()

# Load a model
model = YOLO("yolov8s.pt") # load a pretrained model

# Train the model
results = model.train(data="my_dataset_yolo/data.yaml", epochs=100, imgsz=640, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221 🚀 Python-3.9.23 torch-2.8.0+cu129 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 5805MiB)
# ...
